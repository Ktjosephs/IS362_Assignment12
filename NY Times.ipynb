# %% [markdown]
# ## NY Times API
# ### By Kimesha Josephs

# %% [markdown]
# The New York Times web site provides a rich set of APIs, as described here: http://developer.nytimes.com/docs You’ll need to start by signing up for an API key.
# Your task is to choose one of the New York Times APIs, construct an interface in Python to read in the JSON data, and transform it into a pandas DataFrame.

# %%
import pandas as pd
import json
import urllib.request
from pandas.io.json import json_normalize

# %%
api_key = '12208b8eb1584b3d833db43263dfc3a9'
url = 'https://api.nytimes.com/svc/movies/v2/reviews/search.json?'
string = url+'&api-key='+api_key

response = str(urllib.request.urlopen(string).read(), 'utf-8')

# %%
movie_reviews = pd.read_json(response)
movie_reviews
# Out:
#                                             copyright  has_more  num_results  \
# 0   Copyright (c) 2018 The New York Times Company....      True           20
# 1   Copyright (c) 2018 The New York Times Company....      True           20
# 2   Copyright (c) 2018 The New York Times Company....      True           20
# 3   Copyright (c) 2018 The New York Times Company....      True           20
# 4   Copyright (c) 2018 The New York Times Company....      True           20
# 5   Copyright (c) 2018 The New York Times Company....      True           20
# 6   Copyright (c) 2018 The New York Times Company....      True           20
# 7   Copyright (c) 2018 The New York Times Company....      True           20
# 8   Copyright (c) 2018 The New York Times Company....      True           20
# 9   Copyright (c) 2018 The New York Times Company....      True           20
# 10  Copyright (c) 2018 The New York Times Company....      True           20
# 11  Copyright (c) 2018 The New York Times Company....      True           20
# 12  Copyright (c) 2018 The New York Times Company....      True           20
# 13  Copyright (c) 2018 The New York Times Company....      True           20
# 14  Copyright (c) 2018 The New York Times Company....      True           20
# 15  Copyright (c) 2018 The New York Times Company....      True           20
# 16  Copyright (c) 2018 The New York Times Company....      True           20
# 17  Copyright (c) 2018 The New York Times Company....      True           20
# 18  Copyright (c) 2018 The New York Times Company....      True           20
# 19  Copyright (c) 2018 The New York Times Company....      True           20
#
#                                               results status
# 0   {'mpaa_rating': '', 'byline': 'GLENN KENNY', '...     OK
# 1   {'mpaa_rating': '', 'byline': 'JEANNETTE CATSO...     OK
# 2   {'mpaa_rating': 'PG-13', 'byline': 'GLENN KENN...     OK
# 3   {'mpaa_rating': 'R', 'byline': 'MANOHLA DARGIS...     OK
# 4   {'mpaa_rating': '', 'byline': 'JEANNETTE CATSO...     OK
# 5   {'mpaa_rating': 'R', 'byline': 'JEANNETTE CATS...     OK
# 6   {'mpaa_rating': '', 'byline': 'BEN KENIGSBERG'...     OK
# 7   {'mpaa_rating': '', 'byline': 'TEO BUGBEE', 'c...     OK
# 8   {'mpaa_rating': 'PG', 'byline': 'A. O. SCOTT',...     OK
# 9   {'mpaa_rating': 'PG', 'byline': 'BEN KENIGSBER...     OK
# 10  {'mpaa_rating': '', 'byline': 'BEN KENIGSBERG'...     OK
# 11  {'mpaa_rating': 'R', 'byline': 'JEANNETTE CATS...     OK
# 12  {'mpaa_rating': 'R', 'byline': 'A.O. SCOTT', '...     OK
# 13  {'mpaa_rating': 'R', 'byline': 'GLENN KENNY', ...     OK
# 14  {'mpaa_rating': '', 'byline': 'KEN JAWOROWSKI'...     OK
# 15  {'mpaa_rating': '', 'byline': 'GLENN KENNY', '...     OK
# 16  {'mpaa_rating': 'Not Rated', 'byline': 'JEANNE...     OK
# 17  {'mpaa_rating': '', 'byline': 'MANOHLA DARGIS'...     OK
# 18  {'mpaa_rating': '', 'byline': 'BEN KENIGSBERG'...     OK
# 19  {'mpaa_rating': 'R', 'byline': 'TEO BUGBEE', '...     OK
